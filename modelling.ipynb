# %%
import re
from collections import Counter,defaultdict 		
import numpy as np

words_sv = re.findall(r'\w+', open('/content/europarl-v7.sv-en.lc.sv').read())
words_en = re.findall(r'\w+', open('/content/europarl-v7.sv-en.lc.en').read())

# %% [markdown]
# ### **(a) Warmup**

# %%
words_freq_sv = Counter(words_sv)
words_freq_en = Counter(words_en)
total_words_sv = sum(words_freq_sv.values())
total_words_en = sum(words_freq_en.values())
print("10 most frequent words in English language")
print(words_freq_en.most_common(10))
print("10 most frequent words in Swedish language")
print(words_freq_sv.most_common(10))
print("\nThe probability that randomly picked word is 'speaker'")
print((words_freq_en['speaker']/total_words_en) +( words_freq_sv['speaker']/total_words_sv))
print("The probability that randomly picked word is 'zebra'")
print((words_freq_en['zebra']/total_words_en) +( words_freq_sv['zebra']/total_words_sv))
# Out:
# 10 most frequent words in English language
# [('the', 19327), ('of', 9344), ('to', 8814), ('and', 6949), ('in', 6124), ('is', 4400), ('that', 4357), ('a', 4271), ('we', 3223), ('this', 3222)]
# 10 most frequent words in Swedish language
# [('att', 9181), ('och', 7038), ('i', 5954), ('det', 5687), ('som', 5028), ('för', 4959), ('av', 4013), ('är', 3840), ('en', 3724), ('vi', 3211)]
#
# The probability that randomly picked word is 'speaker'
# 3.890702388502196e-05
# The probability that randomly picked word is 'zebra'
# 0.0

# %% [markdown]
# ### **(b) Language modeling**

# %%
def cal_prob_bigram(bigram_freq,words_freq):
  prob = {}
  for bigram in bigram_freq.items():
    prob[bigram[0]] = bigram[1]/words_freq[bigram[0][0]]
  return prob

def cal_prob_sentence(input_string,bigram_prob ):
  list_words=input_string.split(' ')
  bigram_list = [(list_words[i],list_words[i+1]) for i in range(len(list_words)-1)]
  prob_sentence = 1
  count_bigrams_common = 0
  for bi in bigram_list:
    if bi in bigram_prob:
      count_bigrams_common+=1
      prob_sentence *= bigram_prob[bi]
  if(count_bigrams_common==0):
    prob_sentence = 0
  return prob_sentence

# %%
data =  open('/content/europarl-v7.sv-en.lc.en').read().split(' ')
bigram_freq = Counter((data[idx],data[idx+1]) for idx in range(len(data) - 1)) 
words_freq = Counter(data)
bigram_prob = cal_prob_bigram(bigram_freq, words_freq)

# %%
input1 ="sweety if you  wish"
input2 = "sweety thank you"
input3 = "at the request of a french member , mr zimeray , a petition has already been presented , which many people signed , including myself . however , i would ask you , in accordance with the line which is now constantly followed by the european parliament and by the whole of the european community , to make representations , using the weight of your prestigious office and the institution you represent , to the president and to the governor of texas , mr bush , who has the power to order a stay of execution and to reprieve the condemned person .this is all in accordance with the principles that we have always upheld ."
input4 = "I like zebra"

print("Probabilities of different sentences: ")
print(input1)
print(cal_prob_sentence(input1,bigram_prob))
print('\n')
print(input2)
print(cal_prob_sentence(input2,bigram_prob))
print('\n')
print(input3)
print(cal_prob_sentence(input3,bigram_prob))
print('\n')
print(input4)
print(cal_prob_sentence(input4,bigram_prob))
print('\n')
# Out:
# Probabilities of different sentences:
# sweety if you  wish
# 0.08854166666666667
#
#
# sweety thank you
# 0.20512820512820512
#
#
# at the request of a french member , mr zimeray , a petition has already been presented , which many people signed , including myself . however , i would ask you , in accordance with the line which is now constantly followed by the european parliament and by the whole of the european community , to make representations , using the weight of your prestigious office and the institution you represent , to the president and to the governor of texas , mr bush , who has the power to order a stay of execution and to reprieve the condemned person .this is all in accordance with the principles that we have always upheld .
# 8.52526689177826e-189
#
#
# I like zebra
# 0

# %% [markdown]
# ### **(c) Translation modeling**

# %%
eng = open('/content/europarl-v7.sv-en.lc.en').read()
sve = open('/content/europarl-v7.sv-en.lc.sv').read()

eng_sentences = eng.split('\n')[:10000]
#eng_sentences.pop()
sve_sentences = sve.split('\n')[:10000]
#sve_sentences.pop()

# %%
t  =  defaultdict ( float )

for i in range(len(eng_sentences)):
  e = eng_sentences[i]
  s = sve_sentences[i]
  eng_words = list(set(e.split()))
  sve_words = list(set(s.split()))
  eng_words.append("NULL")
  for each_s in sve_words:
    for each_e in eng_words:
      t [( each_s, each_e  )] =  1.0

# %%
def get_top(t,word,count):
  dict_ = dict( filter(lambda elem: elem[0][1] == word, t.items()))
  dict_sorted = dict(sorted(dict_.items(), key=lambda item: item[1],reverse=True))
  return(list(dict_sorted.items())[:count])

num_iterations = 5
for ite in range(num_iterations):
  count  =  defaultdict ( float )
  total_e  =  defaultdict ( float )
  total_s  =  defaultdict ( float )
  for i in range(len(eng_sentences)):
    e = eng_sentences[i].split(' ')
    s = sve_sentences[i].split(' ')
    
    for s_word in s:
      #print(s_word)
      total_s [ s_word ] =  0.0
      for e_word in e:
        total_s [ s_word ] +=  t [(s_word  , e_word )]

    for s_word in s:
      for e_word in e:
        sigma = t [(s_word  , e_word )]/total_s[ s_word ] # Compute alignment prob.
        count[(e_word  , s_word )] += sigma # Update pseudocount
        total_e[e_word]+= sigma # Update pseudocount

# %%
t
# Out:
# defaultdict(float,
#             {('den', 'december'): 1.0,
#              ('den', 'wish'): 1.0,
#              ('den', 'session'): 1.0,
#              ('den', 'a'): 1.0,
#              ('den', 'period'): 1.0,
#              ('den', 'once'): 1.0,
#              ('den', 'year'): 1.0,
#              ('den', 'would'): 1.0,
#              ('den', 'festive'): 1.0,
#              ('den', '17'): 1.0,
#              ('den', '1999'): 1.0,
#              ('den', 'parliament'): 1.0,
#              ('den', 'new'): 1.0,
#              ('den', 'to'): 1.0,
#              ('den', 'hope'): 1.0,
#              ('den', 'on'): 1.0,
#              ('den', 'and'): 1.0,
#              ('den', 'i'): 1.0,
#              ('den', ','): 1.0,
#              ('den', 'like'): 1.0,
#              ('den', 'friday'): 1.0,
#              ('den', 'european'): 1.0,
#              ('den', 'of'): 1.0,
#              ('den', 'in'): 1.0,
#              ('den', 'resumed'): 1.0,
#              ('den', 'adjourned'): 1.0,
#              ('den', 'happy'): 1.0,
#              ('den', 'again'): 1.0,
#              ('den', 'declare'): 1.0,
#              ('den', 'you'): 1.0,
#              ('den', 'pleasant'): 1.0,
#              ('den', 'the'): 1.0,
#              ('den', '.'): 1.0,
#              ('den', 'that'): 1.0,
#              ('den', 'enjoyed'): 1.0,
#              ('den', 'NULL'): 1.0,
#              ('december', 'december'): 1.0,
#              ('december', 'wish'): 1.0,
#              ('december', 'session'): 1.0,
#              ('december', 'a'): 1.0,
#              ('december', 'period'): 1.0,
#              ('december', 'once'): 1.0,
#              ('december', 'year'): 1.0,
#              ('december', 'would'): 1.0,
#              ('december', 'festive'): 1.0,
#              ('december', '17'): 1.0,
#              ('december', '1999'): 1.0,
#              ('december', 'parliament'): 1.0,
#              ('december', 'new'): 1.0,
#              ('december', 'to'): 1.0,
#              ('december', 'hope'): 1.0,
#              ('december', 'on'): 1.0,
#              ('december', 'and'): 1.0,
#              ('december', 'i'): 1.0,
#              ('december', ','): 1.0,
#              ('december', 'like'): 1.0,
#              ('december', 'friday'): 1.0,
#              ('december', 'european'): 1.0,
#              ('december', 'of'): 1.0,
#              ('december', 'in'): 1.0,
#              ('december', 'resumed'): 1.0,
#              ('december', 'adjourned'): 1.0,
#              ('december', 'happy'): 1.0,
#              ('december', 'again'): 1.0,
#              ('december', 'declare'): 1.0,
#              ('december', 'you'): 1.0,
#              ('december', 'pleasant'): 1.0,
#              ('december', 'the'): 1.0,
#              ('december', '.'): 1.0,
#              ('december', 'that'): 1.0,
#              ('december', 'enjoyed'): 1.0,
#              ('december', 'NULL'): 1.0,
#              ('en', 'december'): 1.0,
#              ('en', 'wish'): 1.0,
#              ('en', 'session'): 1.0,
#              ('en', 'a'): 1.0,
#              ('en', 'period'): 1.0,
#              ('en', 'once'): 1.0,
#              ('en', 'year'): 1.0,
#              ('en', 'would'): 1.0,
#              ('en', 'festive'): 1.0,
#              ('en', '17'): 1.0,
#              ('en', '1999'): 1.0,
#              ('en', 'parliament'): 1.0,
#              ('en', 'new'): 1.0,
#              ('en', 'to'): 1.0,
#              ('en', 'hope'): 1.0,
#              ('en', 'on'): 1.0,
#              ('en', 'and'): 1.0,
#              ('en', 'i'): 1.0,
#              ('en', ','): 1.0,
#              ('en', 'like'): 1.0,
#              ('en', 'friday'): 1.0,
#              ('en', 'european'): 1.0,
#              ('en', 'of'): 1.0,
#              ('en', 'in'): 1.0,
#              ('en', 'resumed'): 1.0,
#              ('en', 'adjourned'): 1.0,
#              ('en', 'happy'): 1.0,
#              ('en', 'again'): 1.0,
#              ('en', 'declare'): 1.0,
#              ('en', 'you'): 1.0,
#              ('en', 'pleasant'): 1.0,
#              ('en', 'the'): 1.0,
#              ('en', '.'): 1.0,
#              ('en', 'that'): 1.0,
#              ('en', 'enjoyed'): 1.0,
#              ('en', 'NULL'): 1.0,
#              ('gott', 'december'): 1.0,
#              ('gott', 'wish'): 1.0,
#              ('gott', 'session'): 1.0,
#              ('gott', 'a'): 1.0,
#              ('gott', 'period'): 1.0,
#              ('gott', 'once'): 1.0,
#              ('gott', 'year'): 1.0,
#              ('gott', 'would'): 1.0,
#              ('gott', 'festive'): 1.0,
#              ('gott', '17'): 1.0,
#              ('gott', '1999'): 1.0,
#              ('gott', 'parliament'): 1.0,
#              ('gott', 'new'): 1.0,
#              ('gott', 'to'): 1.0,
#              ('gott', 'hope'): 1.0,
#              ('gott', 'on'): 1.0,
#              ('gott', 'and'): 1.0,
#              ('gott', 'i'): 1.0,
#              ('gott', ','): 1.0,
#              ('gott', 'like'): 1.0,
#              ('gott', 'friday'): 1.0,
#              ('gott', 'european'): 1.0,
#              ('gott', 'of'): 1.0,
#              ('gott', 'in'): 1.0,
#              ('gott', 'resumed'): 1.0,
#              ('gott', 'adjourned'): 1.0,
#              ('gott', 'happy'): 1.0,
#              ('gott', 'again'): 1.0,
#              ('gott', 'declare'): 1.0,
#              ('gott', 'you'): 1.0,
#              ('gott', 'pleasant'): 1.0,
#              ('gott', 'the'): 1.0,
#              ('gott', '.'): 1.0,
#              ('gott', 'that'): 1.0,
#              ('gott', 'enjoyed'): 1.0,
#              ('gott', 'NULL'): 1.0,
#              ('session', 'december'): 1.0,
#              ('session', 'wish'): 1.0,
#              ('session', 'session'): 1.0,
#              ('session', 'a'): 1.0,
#              ('session', 'period'): 1.0,
#              ('session', 'once'): 1.0,
#              ('session', 'year'): 1.0,
#              ('session', 'would'): 1.0,
#              ('session', 'festive'): 1.0,
#              ('session', '17'): 1.0,
#              ('session', '1999'): 1.0,
#              ('session', 'parliament'): 1.0,
#              ('session', 'new'): 1.0,
#              ('session', 'to'): 1.0,
#              ('session', 'hope'): 1.0,
#              ('session', 'on'): 1.0,
#              ('session', 'and'): 1.0,
#              ('session', 'i'): 1.0,
#              ('session', ','): 1.0,
#              ('session', 'like'): 1.0,
#              ('session', 'friday'): 1.0,
#              ('session', 'european'): 1.0,
#              ('session', 'of'): 1.0,
#              ('session', 'in'): 1.0,
#              ('session', 'resumed'): 1.0,
#              ('session', 'adjourned'): 1.0,
#              ('session', 'happy'): 1.0,
#              ('session', 'again'): 1.0,
#              ('session', 'declare'): 1.0,
#              ('session', 'you'): 1.0,
#              ('session', 'pleasant'): 1.0,
#              ('session', 'the'): 1.0,
#              ('session', '.'): 1.0,
#              ('session', 'that'): 1.0,
#              ('session', 'enjoyed'): 1.0,
#              ('session', 'NULL'): 1.0,
#              ('semester', 'december'): 1.0,
#              ('semester', 'wish'): 1.0,
#              ('semester', 'session'): 1.0,
#              ('semester', 'a'): 1.0,
#              ('semester', 'period'): 1.0,
#              ('semester', 'once'): 1.0,
#              ('semester', 'year'): 1.0,
#              ('semester', 'would'): 1.0,
#              ('semester', 'festive'): 1.0,
#              ('semester', '17'): 1.0,
#              ('semester', '1999'): 1.0,
#              ('semester', 'parliament'): 1.0,
#              ('semester', 'new'): 1.0,
#              ('semester', 'to'): 1.0,
#              ('semester', 'hope'): 1.0,
#              ('semester', 'on'): 1.0,
#              ('semester', 'and'): 1.0,
#              ('semester', 'i'): 1.0,
#              ('semester', ','): 1.0,
#              ('semester', 'like'): 1.0,
#              ('semester', 'friday'): 1.0,
#              ('semester', 'european'): 1.0,
#              ('semester', 'of'): 1.0,
#              ('semester', 'in'): 1.0,
#              ('semester', 'resumed'): 1.0,
#              ('semester', 'adjourned'): 1.0,
#              ('semester', 'happy'): 1.0,
#              ('semester', 'again'): 1.0,
#              ('semester', 'declare'): 1.0,
#              ('semester', 'you'): 1.0,
#              ('semester', 'pleasant'): 1.0,
#              ('semester', 'the'): 1.0,
#              ('semester', '.'): 1.0,
#              ('semester', 'that'): 1.0,
#              ('semester', 'enjoyed'): 1.0,
#              ('semester', 'NULL'): 1.0,
#              ('er', 'december'): 1.0,
#              ('er', 'wish'): 1.0,
#              ('er', 'session'): 1.0,
#              ('er', 'a'): 1.0,
#              ('er', 'period'): 1.0,
#              ('er', 'once'): 1.0,
#              ('er', 'year'): 1.0,
#              ('er', 'would'): 1.0,
#              ('er', 'festive'): 1.0,
#              ('er', '17'): 1.0,
#              ('er', '1999'): 1.0,
#              ('er', 'parliament'): 1.0,
#              ('er', 'new'): 1.0,
#              ('er', 'to'): 1.0,
#              ('er', 'hope'): 1.0,
#              ('er', 'on'): 1.0,
#              ('er', 'and'): 1.0,
#              ('er', 'i'): 1.0,
#              ('er', ','): 1.0,
#              ('er', 'like'): 1.0,
#              ('er', 'friday'): 1.0,
#              ('er', 'european'): 1.0,
#              ('er', 'of'): 1.0,
#              ('er', 'in'): 1.0,
#              ('er', 'resumed'): 1.0,
#              ('er', 'adjourned'): 1.0,
#              ('er', 'happy'): 1.0,
#              ('er', 'again'): 1.0,
#              ('er', 'declare'): 1.0,
#              ('er', 'you'): 1.0,
#              ('er', 'pleasant'): 1.0,
#              ('er', 'the'): 1.0,
#              ('er', '.'): 1.0,
#              ('er', 'that'): 1.0,
#              ('er', 'enjoyed'): 1.0,
#              ('er', 'NULL'): 1.0,
#              ('nytt', 'december'): 1.0,
#              ('nytt', 'wish'): 1.0,
#              ('nytt', 'session'): 1.0,
#              ('nytt', 'a'): 1.0,
#              ('nytt', 'period'): 1.0,
#              ('nytt', 'once'): 1.0,
#              ('nytt', 'year'): 1.0,
#              ('nytt', 'would'): 1.0,
#              ('nytt', 'festive'): 1.0,
#              ('nytt', '17'): 1.0,
#              ('nytt', '1999'): 1.0,
#              ('nytt', 'parliament'): 1.0,
#              ('nytt', 'new'): 1.0,
#              ('nytt', 'to'): 1.0,
#              ('nytt', 'hope'): 1.0,
#              ('nytt', 'on'): 1.0,
#              ('nytt', 'and'): 1.0,
#              ('nytt', 'i'): 1.0,
#              ('nytt', ','): 1.0,
#              ('nytt', 'like'): 1.0,
#              ('nytt', 'friday'): 1.0,
#              ('nytt', 'european'): 1.0,
#              ('nytt', 'of'): 1.0,
#              ('nytt', 'in'): 1.0,
#              ('nytt', 'resumed'): 1.0,
#              ('nytt', 'adjourned'): 1.0,
#              ('nytt', 'happy'): 1.0,
#              ('nytt', 'again'): 1.0,
#              ('nytt', 'declare'): 1.0,
#              ('nytt', 'you'): 1.0,
#              ('nytt', 'pleasant'): 1.0,
#              ('nytt', 'the'): 1.0,
#              ('nytt', '.'): 1.0,
#              ('nytt', 'that'): 1.0,
#              ('nytt', 'enjoyed'): 1.0,
#              ('nytt', 'NULL'): 1.0,
#              ('17', 'december'): 1.0,
#              ('17', 'wish'): 1.0,
#              ('17', 'session'): 1.0,
#              ('17', 'a'): 1.0,
#              ('17', 'period'): 1.0,
#              ('17', 'once'): 1.0,
#              ('17', 'year'): 1.0,
#              ('17', 'would'): 1.0,
#              ('17', 'festive'): 1.0,
#              ('17', '17'): 1.0,
#              ('17', '1999'): 1.0,
#              ('17', 'parliament'): 1.0,
#              ('17', 'new'): 1.0,
#              ('17', 'to'): 1.0,
#              ('17', 'hope'): 1.0,
#              ('17', 'on'): 1.0,
#              ('17', 'and'): 1.0,
#              ('17', 'i'): 1.0,
#              ('17', ','): 1.0,
#              ('17', 'like'): 1.0,
#              ('17', 'friday'): 1.0,
#              ('17', 'european'): 1.0,
#              ('17', 'of'): 1.0,
#              ('17', 'in'): 1.0,
#              ('17', 'resumed'): 1.0,
#              ('17', 'adjourned'): 1.0,
#              ('17', 'happy'): 1.0,
#              ('17', 'again'): 1.0,
#              ('17', 'declare'): 1.0,
#              ('17', 'you'): 1.0,
#              ('17', 'pleasant'): 1.0,
#              ('17', 'the'): 1.0,
#              ('17', '.'): 1.0,
#              ('17', 'that'): 1.0,
#              ('17', 'enjoyed'): 1.0,
#              ('17', 'NULL'): 1.0,
#              ('jag', 'december'): 1.0,
#              ('jag', 'wish'): 1.0,
#              ('jag', 'session'): 1.0,
#              ('jag', 'a'): 1.0,
#              ('jag', 'period'): 1.0,
#              ('jag', 'once'): 1.0,
#              ('jag', 'year'): 1.0,
#              ('jag', 'would'): 1.0,
#              ('jag', 'festive'): 1.0,
#              ('jag', '17'): 1.0,
#              ('jag', '1999'): 1.0,
#              ('jag', 'parliament'): 1.0,
#              ('jag', 'new'): 1.0,
#              ('jag', 'to'): 1.0,
#              ('jag', 'hope'): 1.0,
#              ('jag', 'on'): 1.0,
#              ('jag', 'and'): 1.0,
#              ('jag', 'i'): 1.0,
#              ('jag', ','): 1.0,
#              ('jag', 'like'): 1.0,
#              ('jag', 'friday'): 1.0,
#              ('jag', 'european'): 1.0,
#              ('jag', 'of'): 1.0,
#              ('jag', 'in'): 1.0,
#              ('jag', 'resumed'): 1.0,
#              ('jag', 'adjourned'): 1.0,
#              ('jag', 'happy'): 1.0,
#              ('jag', 'again'): 1.0,
#              ('jag', 'declare'): 1.0,
#              ('jag', 'you'): 1.0,
#              ('jag', 'pleasant'): 1.0,
#              ('jag', 'the'): 1.0,
#              ('jag', '.'): 1.0,
#              ('jag', 'that'): 1.0,
#              ('jag', 'enjoyed'): 1.0,
#              ('jag', 'NULL'): 1.0,
#              ('vill', 'december'): 1.0,
#              ('vill', 'wish'): 1.0,
#              ('vill', 'session'): 1.0,
#              ('vill', 'a'): 1.0,
#              ('vill', 'period'): 1.0,
#              ('vill', 'once'): 1.0,
#              ('vill', 'year'): 1.0,
#              ('vill', 'would'): 1.0,
#              ('vill', 'festive'): 1.0,
#              ('vill', '17'): 1.0,
#              ('vill', '1999'): 1.0,
#              ('vill', 'parliament'): 1.0,
#              ('vill', 'new'): 1.0,
#              ('vill', 'to'): 1.0,
#              ('vill', 'hope'): 1.0,
#              ('vill', 'on'): 1.0,
#              ('vill', 'and'): 1.0,
#              ('vill', 'i'): 1.0,
#              ('vill', ','): 1.0,
#              ('vill', 'like'): 1.0,
#              ('vill', 'friday'): 1.0,
#              ('vill', 'european'): 1.0,
#              ('vill', 'of'): 1.0,
#              ('vill', 'in'): 1.0,
#              ('vill', 'resumed'): 1.0,
#              ('vill', 'adjourned'): 1.0,
#              ('vill', 'happy'): 1.0,
#              ('vill', 'again'): 1.0,
#              ('vill', 'declare'): 1.0,
#              ('vill', 'you'): 1.0,
#              ('vill', 'pleasant'): 1.0,
#              ('vill', 'the'): 1.0,
#              ('vill', '.'): 1.0,
#              ('vill', 'that'): 1.0,
#              ('vill', 'enjoyed'): 1.0,
#              ('vill', 'NULL'): 1.0,
#              ('ni', 'december'): 1.0,
#              ('ni', 'wish'): 1.0,
#              ('ni', 'session'): 1.0,
#              ('ni', 'a'): 1.0,
#              ('ni', 'period'): 1.0,
#              ('ni', 'once'): 1.0,
#              ('ni', 'year'): 1.0,
#              ('ni', 'would'): 1.0,
#              ('ni', 'festive'): 1.0,
#              ('ni', '17'): 1.0,
#              ('ni', '1999'): 1.0,
#              ('ni', 'parliament'): 1.0,
#              ('ni', 'new'): 1.0,
#              ('ni', 'to'): 1.0,
#              ('ni', 'hope'): 1.0,
#              ('ni', 'on'): 1.0,
#              ('ni', 'and'): 1.0,
#              ('ni', 'i'): 1.0,
#              ('ni', ','): 1.0,
#              ('ni', 'like'): 1.0,
#              ('ni', 'friday'): 1.0,
#              ('ni', 'european'): 1.0,
#              ('ni', 'of'): 1.0,
#              ('ni', 'in'): 1.0,
#              ('ni', 'resumed'): 1.0,
#              ('ni', 'adjourned'): 1.0,
#              ('ni', 'happy'): 1.0,
#              ('ni', 'again'): 1.0,
#              ('ni', 'declare'): 1.0,
#              ('ni', 'you'): 1.0,
#              ('ni', 'pleasant'): 1.0,
#              ('ni', 'the'): 1.0,
#              ('ni', '.'): 1.0,
#              ('ni', 'that'): 1.0,
#              ('ni', 'enjoyed'): 1.0,
#              ('ni', 'NULL'): 1.0,
#              ('och', 'december'): 1.0,
#              ('och', 'wish'): 1.0,
#              ('och', 'session'): 1.0,
#              ('och', 'a'): 1.0,
#              ('och', 'period'): 1.0,
#              ('och', 'once'): 1.0,
#              ('och', 'year'): 1.0,
#              ('och', 'would'): 1.0,
#              ('och', 'festive'): 1.0,
#              ('och', '17'): 1.0,
#              ('och', '1999'): 1.0,
#              ('och', 'parliament'): 1.0,
#              ('och', 'new'): 1.0,
#              ('och', 'to'): 1.0,
#              ('och', 'hope'): 1.0,
#              ('och', 'on'): 1.0,
#              ('och', 'and'): 1.0,
#              ('och', 'i'): 1.0,
#              ('och', ','): 1.0,
#              ('och', 'like'): 1.0,
#              ('och', 'friday'): 1.0,
#              ('och', 'european'): 1.0,
#              ('och', 'of'): 1.0,
#              ('och', 'in'): 1.0,
#              ('och', 'resumed'): 1.0,
#              ('och', 'adjourned'): 1.0,
#              ('och', 'happy'): 1.0,
#              ('och', 'again'): 1.0,
#              ('och', 'declare'): 1.0,
#              ('och', 'you'): 1.0,
#              ('och', 'pleasant'): 1.0,
#              ('och', 'the'): 1.0,
#              ('och', '.'): 1.0,
#              ('och', 'that'): 1.0,
#              ('och', 'enjoyed'): 1.0,
#              ('och', 'NULL'): 1.0,
#              ('önska', 'december'): 1.0,
#              ('önska', 'wish'): 1.0,
#              ('önska', 'session'): 1.0,
#              ('önska', 'a'): 1.0,
#              ('önska', 'period'): 1.0,
#              ('önska', 'once'): 1.0,
#              ('önska', 'year'): 1.0,
#              ('önska', 'would'): 1.0,
#              ('önska', 'festive'): 1.0,
#              ('önska', '17'): 1.0,
#              ('önska', '1999'): 1.0,
#              ('önska', 'parliament'): 1.0,
#              ('önska', 'new'): 1.0,
#              ('önska', 'to'): 1.0,
#              ('önska', 'hope'): 1.0,
#              ('önska', 'on'): 1.0,
#              ('önska', 'and'): 1.0,
#              ('önska', 'i'): 1.0,
#              ('önska', ','): 1.0,
#              ('önska', 'like'): 1.0,
#              ('önska', 'friday'): 1.0,
#              ('önska', 'european'): 1.0,
#              ('önska', 'of'): 1.0,
#              ('önska', 'in'): 1.0,
#              ('önska', 'resumed'): 1.0,
#              ('önska', 'adjourned'): 1.0,
#              ('önska', 'happy'): 1.0,
#              ('önska', 'again'): 1.0,
#              ('önska', 'declare'): 1.0,
#              ('önska', 'you'): 1.0,
#              ('önska', 'pleasant'): 1.0,
#              ('önska', 'the'): 1.0,
#              ('önska', '.'): 1.0,
#              ('önska', 'that'): 1.0,
#              ('önska', 'enjoyed'): 1.0,
#              ('önska', 'NULL'): 1.0,
#              ('år', 'december'): 1.0,
#              ('år', 'wish'): 1.0,
#              ('år', 'session'): 1.0,
#              ('år', 'a'): 1.0,
#              ('år', 'period'): 1.0,
#              ('år', 'once'): 1.0,
#              ('år', 'year'): 1.0,
#              ('år', 'would'): 1.0,
#              ('år', 'festive'): 1.0,
#              ('år', '17'): 1.0,
#              ('år', '1999'): 1.0,
#              ('år', 'parliament'): 1.0,
#              ('år', 'new'): 1.0,
#              ('år', 'to'): 1.0,
#              ('år', 'hope'): 1.0,
#              ('år', 'on'): 1.0,
#              ('år', 'and'): 1.0,
#              ('år', 'i'): 1.0,
#              ('år', ','): 1.0,
#              ('år', 'like'): 1.0,
#              ('år', 'friday'): 1.0,
#              ('år', 'european'): 1.0,
#              ('år', 'of'): 1.0,
#              ('år', 'in'): 1.0,
#              ('år', 'resumed'): 1.0,
#              ('år', 'adjourned'): 1.0,
#              ('år', 'happy'): 1.0,
#              ('år', 'again'): 1.0,
#              ('år', 'declare'): 1.0,
#              ('år', 'you'): 1.0,
#              ('år', 'pleasant'): 1.0,
#              ('år', 'the'): 1.0,
#              ('år', '.'): 1.0,
#              ('år', 'that'): 1.0,
#              ('år', 'enjoyed'): 1.0,
#              ('år', 'NULL'): 1.0,
#              ('återupptagen', 'december'): 1.0,
#              ('återupptagen', 'wish'): 1.0,
#              ('återupptagen', 'session'): 1.0,
#              ('återupptagen', 'a'): 1.0,
#              ('återupptagen', 'period'): 1.0,
#              ('återupptagen', 'once'): 1.0,
#              ('återupptagen', 'year'): 1.0,
#              ('återupptagen', 'would'): 1.0,
#              ('återupptagen', 'festive'): 1.0,
#              ('återupptagen', '17'): 1.0,
#              ('återupptagen', '1999'): 1.0,
#              ('återupptagen', 'parliament'): 1.0,
#              ('återupptagen', 'new'): 1.0,
#              ('återupptagen', 'to'): 1.0,
#              ('återupptagen', 'hope'): 1.0,
#              ('återupptagen', 'on'): 1.0,
#              ('återupptagen', 'and'): 1.0,
#              ('återupptagen', 'i'): 1.0,
#              ('återupptagen', ','): 1.0,
#              ('återupptagen', 'like'): 1.0,
#              ('återupptagen', 'friday'): 1.0,
#              ('återupptagen', 'european'): 1.0,
#              ('återupptagen', 'of'): 1.0,
#              ('återupptagen', 'in'): 1.0,
#              ('återupptagen', 'resumed'): 1.0,
#              ('återupptagen', 'adjourned'): 1.0,
#              ('återupptagen', 'happy'): 1.0,
#              ('återupptagen', 'again'): 1.0,
#              ('återupptagen', 'declare'): 1.0,
#              ('återupptagen', 'you'): 1.0,
#              ('återupptagen', 'pleasant'): 1.0,
#              ('återupptagen', 'the'): 1.0,
#              ('återupptagen', '.'): 1.0,
#              ('återupptagen', 'that'): 1.0,
#              ('återupptagen', 'enjoyed'): 1.0,
#              ('återupptagen', 'NULL'): 1.0,
#              ('trevlig', 'december'): 1.0,
#              ('trevlig', 'wish'): 1.0,
#              ('trevlig', 'session'): 1.0,
#              ('trevlig', 'a'): 1.0,
#              ('trevlig', 'period'): 1.0,
#              ('trevlig', 'once'): 1.0,
#              ('trevlig', 'year'): 1.0,
#              ('trevlig', 'would'): 1.0,
#              ('trevlig', 'festive'): 1.0,
#              ('trevlig', '17'): 1.0,
#              ('trevlig', '1999'): 1.0,
#              ('trevlig', 'parliament'): 1.0,
#              ('trevlig', 'new'): 1.0,
#              ('trevlig', 'to'): 1.0,
#              ('trevlig', 'hope'): 1.0,
#              ('trevlig', 'on'): 1.0,
#              ('trevlig', 'and'): 1.0,
#              ('trevlig', 'i'): 1.0,
#              ('trevlig', ','): 1.0,
#              ('trevlig', 'like'): 1.0,
#              ('trevlig', 'friday'): 1.0,
#              ('trevlig', 'european'): 1.0,
#              ('trevlig', 'of'): 1.0,
#              ('trevlig', 'in'): 1.0,
#              ('trevlig', 'resumed'): 1.0,
#              ('trevlig', 'adjourned'): 1.0,
#              ('trevlig', 'happy'): 1.0,
#              ('trevlig', 'again'): 1.0,
#              ('trevlig', 'declare'): 1.0,
#              ('trevlig', 'you'): 1.0,
#              ('trevlig', 'pleasant'): 1.0,
#              ('trevlig', 'the'): 1.0,
#              ('trevlig', '.'): 1.0,
#              ('trevlig', 'that'): 1.0,
#              ('trevlig', 'enjoyed'): 1.0,
#              ('trevlig', 'NULL'): 1.0,
#              ('ett', 'december'): 1.0,
#              ('ett', 'wish'): 1.0,
#              ('ett', 'session'): 1.0,
#              ('ett', 'a'): 1.0,
#              ('ett', 'period'): 1.0,
#              ('ett', 'once'): 1.0,
#              ('ett', 'year'): 1.0,
#              ('ett', 'would'): 1.0,
#              ('ett', 'festive'): 1.0,
#              ('ett', '17'): 1.0,
#              ('ett', '1999'): 1.0,
#              ('ett', 'parliament'): 1.0,
#              ('ett', 'new'): 1.0,
#              ('ett', 'to'): 1.0,
#              ('ett', 'hope'): 1.0,
#              ('ett', 'on'): 1.0,
#              ('ett', 'and'): 1.0,
#              ('ett', 'i'): 1.0,
#              ('ett', ','): 1.0,
#              ('ett', 'like'): 1.0,
#              ('ett', 'friday'): 1.0,
#              ('ett', 'european'): 1.0,
#              ('ett', 'of'): 1.0,
#              ('ett', 'in'): 1.0,
#              ('ett', 'resumed'): 1.0,
#              ('ett', 'adjourned'): 1.0,
#              ('ett', 'happy'): 1.0,
#              ('ett', 'again'): 1.0,
#              ('ett', 'declare'): 1.0,
#              ('ett', 'you'): 1.0,
#              ('ett', 'pleasant'): 1.0,
#              ('ett', 'the'): 1.0,
#              ('ett', '.'): 1.0,
#              ('ett', 'that'): 1.0,
#              ('ett', 'enjoyed'): 1.0,
#              ('ett', 'NULL'): 1.0,
#              ('förklarar', 'december'): 1.0,
#              ('förklarar', 'wish'): 1.0,
#              ('förklarar', 'session'): 1.0,
#              ('förklarar', 'a'): 1.0,
#              ('förklarar', 'period'): 1.0,
#              ('förklarar', 'once'): 1.0,
#              ('förklarar', 'year'): 1.0,
#              ('förklarar', 'would'): 1.0,
#              ('förklarar', 'festive'): 1.0,
#              ('förklarar', '17'): 1.0,
#              ('förklarar', '1999'): 1.0,
#              ('förklarar', 'parliament'): 1.0,
#              ('förklarar', 'new'): 1.0,
#              ('förklarar', 'to'): 1.0,
#              ('förklarar', 'hope'): 1.0,
#              ('förklarar', 'on'): 1.0,
#              ('förklarar', 'and'): 1.0,
#              ('förklarar', 'i'): 1.0,
#              ('förklarar', ','): 1.0,
#              ('förklarar', 'like'): 1.0,
#              ('förklarar', 'friday'): 1.0,
#              ('förklarar', 'european'): 1.0,
#              ('förklarar', 'of'): 1.0,
#              ('förklarar', 'in'): 1.0,
#              ('förklarar', 'resumed'): 1.0,
#              ('förklarar', 'adjourned'): 1.0,
#              ('förklarar', 'happy'): 1.0,
#              ('förklarar', 'again'): 1.0,
#              ('förklarar', 'declare'): 1.0,
#              ('förklarar', 'you'): 1.0,
#              ('förklarar', 'pleasant'): 1.0,
#              ('förklarar', 'the'): 1.0,
#              ('förklarar', '.'): 1.0,
#              ('förklarar', 'that'): 1.0,
#              ('förklarar', 'enjoyed'): 1.0,
#              ('förklarar', 'NULL'): 1.0,
#              ('att', 'december'): 1.0,
#              ('att', 'wish'): 1.0,
#              ('att', 'session'): 1.0,
#              ('att', 'a'): 1.0,
#              ('att', 'period'): 1.0,
#              ('att', 'once'): 1.0,
#              ('att', 'year'): 1.0,
#              ('att', 'would'): 1.0,
#              ('att', 'festive'): 1.0,
#              ('att', '17'): 1.0,
#              ('att', '1999'): 1.0,
#              ('att', 'parliament'): 1.0,
#              ('att', 'new'): 1.0,
#              ('att', 'to'): 1.0,
#              ('att', 'hope'): 1.0,
#              ('att', 'on'): 1.0,
#              ('att', 'and'): 1.0,
#              ('att', 'i'): 1.0,
#              ('att', ','): 1.0,
#              ('att', 'like'): 1.0,
#              ('att', 'friday'): 1.0,
#              ('att', 'european'): 1.0,
#              ('att', 'of'): 1.0,
#              ('att', 'in'): 1.0,
#              ('att', 'resumed'): 1.0,
#              ('att', 'adjourned'): 1.0,
#              ('att', 'happy'): 1.0,
#              ('att', 'again'): 1.0,
#              ('att', 'declare'): 1.0,
#              ('att', 'you'): 1.0,
#              ('att', 'pleasant'): 1.0,
#              ('att', 'the'): 1.0,
#              ('att', '.'): 1.0,
#              ('att', 'that'): 1.0,
#              ('att', 'enjoyed'): 1.0,
#              ('att', 'NULL'): 1.0,
#              ('europaparlamentets', 'december'): 1.0,
#              ('europaparlamentets', 'wish'): 1.0,
#              ('europaparlamentets', 'session'): 1.0,
#              ('europaparlamentets', 'a'): 1.0,
#              ('europaparlamentets', 'period'): 1.0,
#              ('europaparlamentets', 'once'): 1.0,
#              ('europaparlamentets', 'year'): 1.0,
#              ('europaparlamentets', 'would'): 1.0,
#              ('europaparlamentets', 'festive'): 1.0,
#              ('europaparlamentets', '17'): 1.0,
#              ('europaparlamentets', '1999'): 1.0,
#              ('europaparlamentets', 'parliament'): 1.0,
#              ('europaparlamentets', 'new'): 1.0,
#              ('europaparlamentets', 'to'): 1.0,
#              ('europaparlamentets', 'hope'): 1.0,
#              ('europaparlamentets', 'on'): 1.0,
#              ('europaparlamentets', 'and'): 1.0,
#              ('europaparlamentets', 'i'): 1.0,
#              ('europaparlamentets', ','): 1.0,
#              ('europaparlamentets', 'like'): 1.0,
#              ('europaparlamentets', 'friday'): 1.0,
#              ('europaparlamentets', 'european'): 1.0,
#              ('europaparlamentets', 'of'): 1.0,
#              ('europaparlamentets', 'in'): 1.0,
#              ('europaparlamentets', 'resumed'): 1.0,
#              ('europaparlamentets', 'adjourned'): 1.0,
#              ('europaparlamentets', 'happy'): 1.0,
#              ('europaparlamentets', 'again'): 1.0,
#              ('europaparlamentets', 'declare'): 1.0,
#              ('europaparlamentets', 'you'): 1.0,
#              ('europaparlamentets', 'pleasant'): 1.0,
#              ('europaparlamentets', 'the'): 1.0,
#              ('europaparlamentets', '.'): 1.0,
#              ('europaparlamentets', 'that'): 1.0,
#              ('europaparlamentets', 'enjoyed'): 1.0,
#              ('europaparlamentets', 'NULL'): 1.0,
#              ('efter', 'december'): 1.0,
#              ('efter', 'wish'): 1.0,
#              ('efter', 'session'): 1.0,
#              ('efter', 'a'): 1.0,
#              ('efter', 'period'): 1.0,
#              ('efter', 'once'): 1.0,
#              ('efter', 'year'): 1.0,
#              ('efter', 'would'): 1.0,
#              ('efter', 'festive'): 1.0,
#              ('efter', '17'): 1.0,
#              ('efter', '1999'): 1.0,
#              ('efter', 'parliament'): 1.0,
#              ('efter', 'new'): 1.0,
#              ('efter', 'to'): 1.0,
#              ('efter', 'hope'): 1.0,
#              ('efter', 'on'): 1.0,
#              ('efter', 'and'): 1.0,
#              ('efter', 'i'): 1.0,
#              ('efter', ','): 1.0,
#              ('efter', 'like'): 1.0,
#              ('efter', 'friday'): 1.0,
#              ('efter', 'european'): 1.0,
#              ('efter', 'of'): 1.0,
#              ('efter', 'in'): 1.0,
#              ('efter', 'resumed'): 1.0,
#              ('efter', 'adjourned'): 1.0,
#              ('efter', 'happy'): 1.0,
#              ('efter', 'again'): 1.0,
#              ('efter', 'declare'): 1.0,
#              ('efter', 'you'): 1.0,
#              ('efter', 'pleasant'): 1.0,
#              ('efter', 'the'): 1.0,
#              ('efter', '.'): 1.0,
#              ('efter', 'that'): 1.0,
#              ('efter', 'enjoyed'): 1.0,
#              ('efter', 'NULL'): 1.0,
#              ('hoppas', 'december'): 1.0,
#              ('hoppas', 'wish'): 1.0,
#              ('hoppas', 'session'): 1.0,
#              ('hoppas', 'a'): 1.0,
#              ('hoppas', 'period'): 1.0,
#              ('hoppas', 'once'): 1.0,
#              ('hoppas', 'year'): 1.0,
#              ('hoppas', 'would'): 1.0,
#              ('hoppas', 'festive'): 1.0,
#              ('hoppas', '17'): 1.0,
#              ('hoppas', '1999'): 1.0,
#              ('hoppas', 'parliament'): 1.0,
#              ('hoppas', 'new'): 1.0,
#              ('hoppas', 'to'): 1.0,
#              ('hoppas', 'hope'): 1.0,
#              ('hoppas', 'on'): 1.0,
#              ('hoppas', 'and'): 1.0,
#              ('hoppas', 'i'): 1.0,
#              ('hoppas', ','): 1.0,
#              ('hoppas', 'like'): 1.0,
#              ('hoppas', 'friday'): 1.0,
#              ('hoppas', 'european'): 1.0,
#              ('hoppas', 'of'): 1.0,
#              ('hoppas', 'in'): 1.0,
#              ('hoppas', 'resumed'): 1.0,
#              ('hoppas', 'adjourned'): 1.0,
#              ('hoppas', 'happy'): 1.0,
#              ('hoppas', 'again'): 1.0,
#              ('hoppas', 'declare'): 1.0,
#              ('hoppas', 'you'): 1.0,
#              ('hoppas', 'pleasant'): 1.0,
#              ('hoppas', 'the'): 1.0,
#              ('hoppas', '.'): 1.0,
#              ('hoppas', 'that'): 1.0,
#              ('hoppas', 'enjoyed'): 1.0,
#              ('hoppas', 'NULL'): 1.0,
#              ('.', 'december'): 1.0,
#              ('.', 'wish'): 1.0,
#              ('.', 'session'): 1.0,
#              ('.', 'a'): 1.0,
#              ('.', 'period'): 1.0,
#              ('.', 'once'): 1.0,
#              ('.', 'year'): 1.0,
#              ('.', 'would'): 1.0,
#              ('.', 'festive'): 1.0,
#              ('.', '17'): 1.0,
#              ('.', '1999'): 1.0,
#              ('.', 'parliament'): 1.0,
#              ('.', 'new'): 1.0,
#              ('.', 'to'): 1.0,
#              ('.', 'hope'): 1.0,
#              ('.', 'on'): 1.0,
#              ('.', 'and'): 1.0,
#              ('.', 'i'): 1.0,
#              ('.', ','): 1.0,
#              ('.', 'like'): 1.0,
#              ('.', 'friday'): 1.0,
#              ('.', 'european'): 1.0,
#              ('.', 'of'): 1.0,
#              ('.', 'in'): 1.0,
#              ('.', 'resumed'): 1.0,
#              ('.', 'adjourned'): 1.0,
#              ('.', 'happy'): 1.0,
#              ('.', 'again'): 1.0,
#              ('.', 'declare'): 1.0,
#              ('.', 'you'): 1.0,
#              ('.', 'pleasant'): 1.0,
#              ('.', 'the'): 1.0,
#              ('.', '.'): 1.0,
#              ('.', 'that'): 1.0,
#              ('.', 'enjoyed'): 1.0,
#              ('.', 'NULL'): 1.0,
#              ('på', 'december'): 1.0,
#              ('på', 'wish'): 1.0,
#              ('på', 'session'): 1.0,
#              ('på', 'a'): 1.0,
#              ('på', 'period'): 1.0,
#              ('på', 'once'): 1.0,
#              ('på', 'year'): 1.0,
#              ('på', 'would'): 1.0,
#              ('på', 'festive'): 1.0,
#              ('på', '17'): 1.0,
#              ('på', '1999'): 1.0,
#              ('på', 'parliament'): 1.0,
#              ('på', 'new'): 1.0,
#              ('på', 'to'): 1.0,
#              ('på', 'hope'): 1.0,
#              ('på', 'on'): 1.0,
#              ('på', 'and'): 1.0,
#              ('på', 'i'): 1.0,
#              ('på', ','): 1.0,
#              ('på', 'like'): 1.0,
#              ('på', 'friday'): 1.0,
#              ('på', 'european'): 1.0,
#              ('på', 'of'): 1.0,
#              ('på', 'in'): 1.0,
#              ('på', 'resumed'): 1.0,
#              ('på', 'adjourned'): 1.0,
#              ('på', 'happy'): 1.0,
#              ('på', 'again'): 1.0,
#              ('på', 'declare'): 1.0,
#              ('på', 'you'): 1.0,
#              ('på', 'pleasant'): 1.0,
#              ('på', 'the'): 1.0,
#              ('på', '.'): 1.0,
#              ('på', 'that'): 1.0,
#              ('på', 'enjoyed'): 1.0,
#              ('på', 'NULL'): 1.0,
#              ('haft', 'december'): 1.0,
#              ('haft', 'wish'): 1.0,
#              ('haft', 'session'): 1.0,
#              ('haft', 'a'): 1.0,
#              ('haft', 'period'): 1.0,
#              ('haft', 'once'): 1.0,
#              ('haft', 'year'): 1.0,
#              ('haft', 'would'): 1.0,
#              ('haft', 'festive'): 1.0,
#              ('haft', '17'): 1.0,
#              ('haft', '1999'): 1.0,
#              ('haft', 'parliament'): 1.0,
#              ('haft', 'new'): 1.0,
#              ('haft', 'to'): 1.0,
#              ('haft', 'hope'): 1.0,
#              ('haft', 'on'): 1.0,
#              ('haft', 'and'): 1.0,
#              ('haft', 'i'): 1.0,
#              ('haft', ','): 1.0,
#              ('haft', 'like'): 1.0,
#              ('haft', 'friday'): 1.0,
#              ('haft', 'european'): 1.0,
#              ('haft', 'of'): 1.0,
#              ('haft', 'in'): 1.0,
#              ('haft', 'resumed'): 1.0,
#              ('haft', 'adjourned'): 1.0,
#              ('haft', 'happy'): 1.0,
#              ('haft', 'again'): 1.0,
#              ('haft', 'declare'): 1.0,
#              ('haft', 'you'): 1.0,
#              ('haft', 'pleasant'): 1.0,
#              ('haft', 'the'): 1.0,
#              ('haft', '.'): 1.0,
#              ('haft', 'that'): 1.0,
#              ('haft', 'enjoyed'): 1.0,
#              ('haft', 'NULL'): 1.0,
#              ('avbrottet', 'december'): 1.0,
#              ('avbrottet', 'wish'): 1.0,
#              ('avbrottet', 'session'): 1.0,
#              ('avbrottet', 'a'): 1.0,
#              ('avbrottet', 'period'): 1.0,
#              ('avbrottet', 'once'): 1.0,
#              ('avbrottet', 'year'): 1.0,
#              ('avbrottet', 'would'): 1.0,
#              ('avbrottet', 'festive'): 1.0,
#              ('avbrottet', '17'): 1.0,
#              ('avbrottet', '1999'): 1.0,
#              ('avbrottet', 'parliament'): 1.0,
#              ('avbrottet', 'new'): 1.0,
#              ('avbrottet', 'to'): 1.0,
#              ('avbrottet', 'hope'): 1.0,
#              ('avbrottet', 'on'): 1.0,
#              ('avbrottet', 'and'): 1.0,
#              ('avbrottet', 'i'): 1.0,
#              ('avbrottet', ','): 1.0,
#              ('avbrottet', 'like'): 1.0,
#              ('avbrottet', 'friday'): 1.0,
#              ('avbrottet', 'european'): 1.0,
#              ('avbrottet', 'of'): 1.0,
#              ('avbrottet', 'in'): 1.0,
#              ('avbrottet', 'resumed'): 1.0,
#              ('avbrottet', 'adjourned'): 1.0,
#              ('avbrottet', 'happy'): 1.0,
#              ('avbrottet', 'again'): 1.0,
#              ('avbrottet', 'declare'): 1.0,
#              ('avbrottet', 'you'): 1.0,
#              ('avbrottet', 'pleasant'): 1.0,
#              ('avbrottet', 'the'): 1.0,
#              ('avbrottet', '.'): 1.0,
#              ('avbrottet', 'that'): 1.0,
#              ('avbrottet', 'enjoyed'): 1.0,
#              ('avbrottet', 'NULL'): 1.0,
#              ('antal', 'dreaded'): 1.0,
#              ('antal', 'truly'): 1.0,
#              ('antal', 'a'): 1.0,
#              ('antal', 'people'): 1.0,
#              ('antal', 'seen'): 1.0,
#              ('antal', 'number'): 1.0,
#              ('antal', 'natural'): 1.0,
#              ('antal', 'to'): 1.0,
#              ('antal', 'have'): 1.0,
#              ('antal', ','): 1.0,
#              ('antal', 'although'): 1.0,
#              ('antal', '&apos;'): 1.0,
#              ('antal', 'of'): 1.0,
#              ('antal', 'failed'): 1.0,
#              ('antal', 'will'): 1.0,
#              ('antal', 'as'): 1.0,
#              ('antal', 'in'): 1.0,
#              ('antal', 'disasters'): 1.0,
#              ('antal', 'still'): 1.0,
#              ('antal', 'millennium'): 1.0,
#              ('antal', 'were'): 1.0,
#              ('antal', 'you'): 1.0,
#              ('antal', 'bug'): 1.0,
#              ('antal', 'the'): 1.0,
#              ('antal', '.'): 1.0,
#              ('antal', 'dreadful'): 1.0,
#              ('antal', 'that'): 1.0,
#              ('antal', 'countries'): 1.0,
#              ...})

# %% [markdown]
# ### **(d) Decoding**

# %%
input = "thank you"
list_input = input.split(" ")
output = []
for l in list_input:
  sve_word = get_top(t,l,1)
  output.append(sve_word[0][0][0])
print(" ".join(output))
# Out:
# skall den
